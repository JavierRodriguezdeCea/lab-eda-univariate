# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')

# %%
# Loading the housing price dataset (assuming the file name is "housing_price.csv")
tabla = pd.read_csv("C:/Users/Javi/Documents/bootcamp/labs/Semana1_Estadistica/amz_uk_price_prediction_dataset.csv")

# %%
tabla.count()
# Out:
# uid                  2443651
# asin                 2443651
# title                2443651
# stars                2443651
# reviews              2443651
# price                2443651
# isBestSeller         2443651
# boughtInLastMonth    2443651
# category             2443651
# dtype: int64

# %%
tabla.nunique()
# Out:
# uid                  2443651
# asin                 2222742
# title                2077591
# stars                     42
# reviews                19446
# price                  82916
# isBestSeller               2
# boughtInLastMonth         25
# category                 296
# dtype: int64

# %%
tabla_categorias_recuento = tabla['category'].value_counts()
tabla_categorias_recuento
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
#                                            ...
# Motorbike Chassis                            107
# Alexa Built-In Devices                       107
# Plugs                                        107
# Smart Home Security & Lighting               104
# Smart Speakers                                54
# Name: count, Length: 296, dtype: int64

# %%
pt = tabla_categorias_recuento.nlargest(15)
pt
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Manicure & Pedicure Products               18940
# Skin Care                                  18769
# Make-up                                    18756
# Hair Care                                  18735
# Fragrances                                 18564
# Handmade Gifts                             18295
# Handmade Home Décor                        18146
# Luggage and travel gear                    18142
# Handmade Jewellery                         18044
# Handmade Artwork                           17878
# Name: count, dtype: int64

# %%
sns.barplot(x=pt.values, y=pt.index, palette="Set3");
# Out:
# C:\Users\Javi\AppData\Local\Temp\ipykernel_22208\1509687014.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pt.values, y=pt.index, palette="Set3");

# %%
pt.plot.pie(autopct='%1.1f%%', startangle=1, colors=sns.color_palette("Set3"))
# Out:
# <Axes: ylabel='count'>

# %%
tabla
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
tabla['price'].mean()
# Out:
# np.float64(89.24380943923663)

# %%
tabla['price'].mode()
# Out:
# 0    9.99
# Name: price, dtype: float64

# %%
tabla['price'].median()
# Out:
# np.float64(19.09)

# %% [markdown]
# La media se aleja mucho de la moda.

# %%
tabla['price'].var()
# Out:
# np.float64(119445.48532254907)

# %%
tabla['price'].std()
# Out:
# np.float64(345.60886175349884)

# %%
tabla['price'].min()
# Out:
# np.float64(0.0)

# %%
tabla['price'].max()
# Out:
# np.float64(100000.0)

# %%
range_price = tabla['price'].max() - tabla['price'].min()
range_price
# Out:
# np.float64(100000.0)

# %%
rango_intercuartil = tabla['price'].quantile(0.75) -  tabla['price'].quantile(0.25)
rango_intercuartil
# Out:
# np.float64(36.0)

# %% [markdown]
# hay una amplia variedad en los comentarios

# %%
sns.histplot(tabla['price'], kde=True, bins=20, color="salmon")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
tabla['stars'].mean()
# Out:
# np.float64(2.152836472966065)

# %%
tabla['stars'].mode()
# Out:
# 0    0.0
# Name: stars, dtype: float64

# %%
tabla['stars'].median()
# Out:
# np.float64(0.0)

# %% [markdown]
# Si la tendencia general es una puntuacion de cero.

# %%
tabla['stars'].var()
# Out:
# np.float64(4.817434029796862)

# %%
tabla['stars'].std()
# Out:
# np.float64(2.1948653785134207)

# %%
rango_intercuartil = tabla['stars'].quantile(0.75) -  tabla['stars'].quantile(0.25)
rango_intercuartil
# Out:
# np.float64(4.4)

# %% [markdown]
# hay una amplia variacion

# %%
tabla['stars'].skew()
# Out:
# np.float64(0.08120735761080985)

# %%
tabla['stars'].kurtosis()
# Out:
# np.float64(-1.9260061280432985)

# %% [markdown]
# tienden hacia valores mas altos  y mas bajos

# %%
sns.histplot(tabla['stars'], kde=True, bins=200, color="salmon")
# Out:
# <Axes: xlabel='stars', ylabel='Count'>
